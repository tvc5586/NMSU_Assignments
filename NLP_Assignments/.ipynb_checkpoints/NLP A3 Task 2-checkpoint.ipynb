# %% [markdown]
# # NMSU CSCI-5435 Assignment 3 Task 2

# %% [markdown]
# ## Relevent Information

# %%
#Name:               Tianjie Chen
#Email:              tvc5586@nmsu.edu
#File Creation Date: Feb/27/2025
#Purpose of File:    NMSU CSCI-5435 Assignment 3 Task 2
#Last Edit Date:     Feb/27/2025
#Last Edit Note:     File creation
#GenAI used:         False

# %% [markdown]
# ## Load Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import gensim.downloader
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import accuracy_score
from torch.autograd import Variable

# %% [markdown]
# ## Setup

# %%
# USING GPU
print(torch.cuda.device_count())
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# 1

# %%
batch_size = 1024  # BATCH SIZE FOR THIS MODEL
epochs     = 20   # Number of training epochs

# %%
DATA_PATH = "News_Category_Dataset_v2.json"

train_data = pd.read_json(DATA_PATH, lines = True)['short_description']

# %% [markdown]
# ## Preprocessing

# %%
train_data = train_data.str.lower()
train_data = train_data.str.replace("-", " ", regex=True)
train_data = train_data.str.replace(r"[^'\&\w\s]", "", regex=True)
train_data = train_data.str.strip()
train_data = [" ".join(["<start>", x, "<end>"]) for x in train_data]

# %%
print(train_data[0])
# Out:
# <start> she left her husband he killed their children just another day in america <end>

# %%
print(len(train_data))
# Out:
# 200853

# %% [markdown]
# ## Use Pre-trained Tokenizer

# %% [markdown]
# ### Tokenization

# %%
from transformers import BertTokenizerFast

###
# define Vocab
###
class Vocab:
    def __init__(self, list_of_sentence, tokenization, special_token, max_tokens=None):
        # count vocab frequency
        vocab_freq = {}
        tokens = tokenization(list_of_sentence)
        for t in tokens:
            for vocab in t:
                if vocab not in vocab_freq:
                    vocab_freq[vocab] = 0 
                vocab_freq[vocab] += 1
        # sort by frequency
        vocab_freq = {k: v for k, v in sorted(vocab_freq.items(), key=lambda i: i[1], reverse=True)}
        # create vocab list
        self.vocabs = special_token + list(vocab_freq.keys())
        if max_tokens:
            self.vocabs = self.vocabs[:max_tokens]
        self.stoi = {v: i for i, v in enumerate(self.vocabs)}

    def _get_tokens(self, list_of_sentence):
        for sentence in list_of_sentence:
            tokens = tokenizer.tokenize(sentence)
            yield tokens

    def get_itos(self):
        return self.vocabs

    def get_stoi(self):
        return self.stoi

    def append_token(self, token):
        self.vocabs.append(token)
        self.stoi = {v: i for i, v in enumerate(self.vocabs)}

    def __call__(self, list_of_tokens):
        def get_token_index(token):
            if token in self.stoi:
                return self.stoi[token]
            else:
                return 0
        return [get_token_index(t) for t in list_of_tokens]

    def __len__(self):
        return len(self.vocabs)

###
# generate Vocab
###
max_word = 50000

# create tokenizer
tokenizer = BertTokenizerFast.from_pretrained('bert-base-cased')

# Must manually add the start and end tokens, otherwise
# the tokenizer will separate them into three tokens
tokenizer.add_tokens(["<start>", "<end>"])

# define tokenization function
def yield_tokens(data):
    for text in data:
        tokens = tokenizer.tokenize(text)
        yield tokens

# build vocabulary list
vocab = Vocab(
    train_data,
    tokenization=yield_tokens,
    special_token=["<unk>"],
    max_tokens=max_word,
)

# get list for index-to-word, and word-to-index.
itos = vocab.get_itos()
stoi = vocab.get_stoi()

# %%
print(itos)
# Out:
# ['<unk>', '<start>', '<end>', 'the', 'to', 'a', 'and', 'of', "'", 'in', 's', 'is', 'that', 'it', 'i', 'for', 'you', '##s', 'on', 't', 'we', 'with', 'are', 'be', 'as', 'this', 'have', 'but', 'your', 'was', 'not', 'at', 'can', 'from', 'my', 'an', 'or', 'our', 'about', 'what', 'more', 'has', 'they', 'all', 'one', 'by', 're', 'when', 'he', 'out', 'will', 'their', 'who', 'if', 'there', 'new', 'do', 'so', 'us', 'his', 'up', 'time', 'just', 'people', 'am', 'like', 'her', 'me', 'j', 'no', 'how', '##y', 'some', 'don', 'm', '##ing', 'been', 'she', 'g', 'than', '##a', 'p', 'year', '##t', 'most', 'get', 'life', 'day', 'f', 'c', 'said', 'its', 'over', 'after', '##eric', 'many', 'were', 'r', 'these', 'would', 'make', 'b', 'into', 'had', 've', '##n', 'world', 'first', 'them', 'know', '##e', 'may', 'go', '##rump', 'here', '##er', 'want', 'now', '##r', 'even', 'years', 'o', 'way', '##ly', '##an', 'other', 'being', '##p', 'ch', '##l', 'only', 'k', 'love', 'two', 'week', 'could', 'h', 'take', '##ed', 'while', 'good', 'which', '##on', 'think', 'because', 'need', 'also', 'much', 'president', 'back', 'see', '##day', 'women', 'those', 'last', '##d', 'say', 'ma', 'd', 'should', 'work', 'best', 'well', 'every', 'health', '##c', 'un', 'right', 'still', 'help', 'things', 'face', 'where', 'look', 'down', 'never', 'children', 'before', 'old', 'through', 'too', 'home', 'something', 'really', 'off', 'why', 'little', '##uff', 'long', 'any', 'going', 'l', 'sa', 'own', 'made', 'family', 'very', 'news', '##es', '##ia', 'co', '##post', 'de', 'mi', 'man', 'find', 'better', 'check', 'around', 'says', 'few', 'feel', 'state', 'great', 'kids', '##f', 'let', 'always', 'ha', 'v', 'show', 'br', '##b', 'come', 'big', 'ever', '##in', 'then', 'him', 'di', '##o', 'sure', '##ma', 'change', 'did', 'today', 'country', 'might', '##g', 'another', 'll', '##wi', 'often', 'part', 'food', '##ers', 'days', 'since', 'e', 'got', 'each', 'ka', 'doesn', 'thing', 'da', 'three', '##h', 'city', '##ba', 'yo', '##rk', 'between', 'during', 'school', '##m', '##v', 'care', 'style', 'both', 'house', 'keep', '##ald', 'does', 'end', '##book', '##est', 'without', 'w', 'lot', '##i', 'same', 'night', 'child', 'against', 'ca', 'comes', '##ter', '##en', '##tter', 'ho', 'next', 'white', 'whether', 'live', 'real', 'high', 'found', 'la', 'past', 'important', 'place', 'hard', 'making', 'parents', 'men', 'lives', 'republican', 'con', 'put', 'start', 'didn', 'getting', 'car', 'isn', 'black', 'give', '##ic', 'again', '##co', 'mom', 'under', 'n', 'mind', 'yet', 'become', 'heart', '##le', 'se', 'enough', '##ans', 'away', '##ur', 'use', 'yourself', 'mother', 'once', 'must', 'al', 'public', 'states', 'national', 'others', 'told', '##ary', 'different', 'times', 'season', '##ie', '##al', 'believe', 'having', 'person', 'far', 'story', 'everyone', 'read', '##ton', 'someone', 'law', 'lo', 'experience', 'less', 'called', 'em', '##ve', '##us', 'wedding', 'top', '##te', 'former', 'summer', 'young', 'sometimes', 'media', 'ways', 'such', 'na', 'thought', 'social', 'party', 'ta', 'looking', 'doing', 'self', 'five', 'woman', '##rist', 'won', 'video', 'fashion', 'study', 'star', 'ago', 'money', 'easy', '##is', 'together', 'tell', '##li', 'set', 'actually', 'moment', 'least', 'friends', '##ian', 'full', '10', 'nothing', 'body', 'ex', 'red', 'sun', 'everything', 'according', 'percent', 'stop', 'though', 'used', 'month', 'bad', 'en', '##ness', 'makes', 'million', 'travel', '##z', 'sleep', 'th', 'power', '##ce', 'recent', 'already', 'parent', 'below', 'history', 'took', 'human', '##com', '##man', 'bar', 'pin', 'taking', 'political', 'try', '##ra', 'list', '##w', 'free', 'war', 'living', 'government', 'divorce', 'campaign', 'business', 'ins', 'police', 'favorite', 'te', 'healthy', 'job', 'four', 'trying', 'months', 'stress', '##um', 'call', 'future', 'fl', 'fact', '##ful', 'talk', 'matter', 'support', 'le', 'kind', 'post', 'per', '##k', 'united', '##oh', '##rs', 'working', 'came', 'community', 'left', 'happy', 'perfect', '##rn', 'f ...

# %%
print(stoi)
# Out:
# {'<unk>': 0, '<start>': 1, '<end>': 2, 'the': 3, 'to': 4, 'a': 5, 'and': 6, 'of': 7, "'": 8, 'in': 9, 's': 10, 'is': 11, 'that': 12, 'it': 13, 'i': 14, 'for': 15, 'you': 16, '##s': 17, 'on': 18, 't': 19, 'we': 20, 'with': 21, 'are': 22, 'be': 23, 'as': 24, 'this': 25, 'have': 26, 'but': 27, 'your': 28, 'was': 29, 'not': 30, 'at': 31, 'can': 32, 'from': 33, 'my': 34, 'an': 35, 'or': 36, 'our': 37, 'about': 38, 'what': 39, 'more': 40, 'has': 41, 'they': 42, 'all': 43, 'one': 44, 'by': 45, 're': 46, 'when': 47, 'he': 48, 'out': 49, 'will': 50, 'their': 51, 'who': 52, 'if': 53, 'there': 54, 'new': 55, 'do': 56, 'so': 57, 'us': 58, 'his': 59, 'up': 60, 'time': 61, 'just': 62, 'people': 63, 'am': 64, 'like': 65, 'her': 66, 'me': 67, 'j': 68, 'no': 69, 'how': 70, '##y': 71, 'some': 72, 'don': 73, 'm': 74, '##ing': 75, 'been': 76, 'she': 77, 'g': 78, 'than': 79, '##a': 80, 'p': 81, 'year': 82, '##t': 83, 'most': 84, 'get': 85, 'life': 86, 'day': 87, 'f': 88, 'c': 89, 'said': 90, 'its': 91, 'over': 92, 'after': 93, '##eric': 94, 'many': 95, 'were': 96, 'r': 97, 'these': 98, 'would': 99, 'make': 100, 'b': 101, 'into': 102, 'had': 103, 've': 104, '##n': 105, 'world': 106, 'first': 107, 'them': 108, 'know': 109, '##e': 110, 'may': 111, 'go': 112, '##rump': 113, 'here': 114, '##er': 115, 'want': 116, 'now': 117, '##r': 118, 'even': 119, 'years': 120, 'o': 121, 'way': 122, '##ly': 123, '##an': 124, 'other': 125, 'being': 126, '##p': 127, 'ch': 128, '##l': 129, 'only': 130, 'k': 131, 'love': 132, 'two': 133, 'week': 134, 'could': 135, 'h': 136, 'take': 137, '##ed': 138, 'while': 139, 'good': 140, 'which': 141, '##on': 142, 'think': 143, 'because': 144, 'need': 145, 'also': 146, 'much': 147, 'president': 148, 'back': 149, 'see': 150, '##day': 151, 'women': 152, 'those': 153, 'last': 154, '##d': 155, 'say': 156, 'ma': 157, 'd': 158, 'should': 159, 'work': 160, 'best': 161, 'well': 162, 'every': 163, 'health': 164, '##c': 165, 'un': 166, 'right': 167, 'still': 168, 'help': 169, 'things': 170, 'face': 171, 'where': 172, 'look': 173, 'down': 174, 'never': 175, 'children': 176, 'before': 177, 'old': 178, 'through': 179, 'too': 180, 'home': 181, 'something': 182, 'really': 183, 'off': 184, 'why': 185, 'little': 186, '##uff': 187, 'long': 188, 'any': 189, 'going': 190, 'l': 191, 'sa': 192, 'own': 193, 'made': 194, 'family': 195, 'very': 196, 'news': 197, '##es': 198, '##ia': 199, 'co': 200, '##post': 201, 'de': 202, 'mi': 203, 'man': 204, 'find': 205, 'better': 206, 'check': 207, 'around': 208, 'says': 209, 'few': 210, 'feel': 211, 'state': 212, 'great': 213, 'kids': 214, '##f': 215, 'let': 216, 'always': 217, 'ha': 218, 'v': 219, 'show': 220, 'br': 221, '##b': 222, 'come': 223, 'big': 224, 'ever': 225, '##in': 226, 'then': 227, 'him': 228, 'di': 229, '##o': 230, 'sure': 231, '##ma': 232, 'change': 233, 'did': 234, 'today': 235, 'country': 236, 'might': 237, '##g': 238, 'another': 239, 'll': 240, '##wi': 241, 'often': 242, 'part': 243, 'food': 244, '##ers': 245, 'days': 246, 'since': 247, 'e': 248, 'got': 249, 'each': 250, 'ka': 251, 'doesn': 252, 'thing': 253, 'da': 254, 'three': 255, '##h': 256, 'city': 257, '##ba': 258, 'yo': 259, '##rk': 260, 'between': 261, 'during': 262, 'school': 263, '##m': 264, '##v': 265, 'care': 266, 'style': 267, 'both': 268, 'house': 269, 'keep': 270, '##ald': 271, 'does': 272, 'end': 273, '##book': 274, '##est': 275, 'without': 276, 'w': 277, 'lot': 278, '##i': 279, 'same': 280, 'night': 281, 'child': 282, 'against': 283, 'ca': 284, 'comes': 285, '##ter': 286, '##en': 287, '##tter': 288, 'ho': 289, 'next': 290, 'white': 291, 'whether': 292, 'live': 293, 'real': 294, 'high': 295, 'found': 296, 'la': 297, 'past': 298, 'important': 299, 'place': 300, 'hard': 301, 'making': 302, 'parents': 303, 'men': 304, 'lives': 305, 'republican': 306, 'con': 307, 'put': 308, 'start': 309, 'didn': 310, 'getting': 311, 'car': 312, 'isn': 313, 'black': 314, 'give': 315, '##ic': 316, 'again': 317, '##co': 318, 'mom': 319, 'under': 320, 'n' ...

# %% [markdown]
# ### Train-Test Split

# %%
seq_len = 100 + 1
input_seq = []
for s in train_data:
    token_list = vocab(tokenizer.tokenize(s))
    for i in range(seq_len, len(token_list) + 1):
        seq_list = token_list[i-seq_len:i]
        input_seq.append(seq_list)
print("The number of training input sequence :{}".format(len(input_seq)))
input_seq = np.array(input_seq)
# Out:
# The number of training input sequence :16921

# %%
X, y = input_seq[:,:-1], input_seq[:,-1]

# %%
print(X[0])
# Out:
# [    1    25   134     3   647   482    44   501  2061     4   785  1182
#     92     4     3    84  1491     6 11620  1124  1158     9    58   434
#     24    73   271    19   113  3105  2569  4144     3   306   663  2971
#     57  3105  2569     9   468    12    48   685    18     4  1717    12
#     14   846    32  1754    64    94    80    13 11277     5   134     7
#    281   123   229  6205  3553    21    19   113    40    79   449    60
#      4     3  3677  1009  2477   712     4   228    45    68   948  2147
#     27    39 14563   179     3    84     9    59  2838     6  3032 11220
#   1457    29   521   521]

# %%
print(vocab)
# Out:
# <__main__.Vocab object at 0x7e623c5710a0>

# %% [markdown]
# ### Configure Model

# %%
embedding_dim = 128

class SimpleLM(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim=512):
        super().__init__()

        self.embedding = nn.Embedding(
            vocab_size,
            embedding_dim,
        )
        self.hidden = nn.Linear(embedding_dim*(seq_len - 1), hidden_dim)
        self.hidden_l = nn.Linear(hidden_dim, hidden_dim)
        self.classify = nn.Linear(hidden_dim, vocab_size)
        self.relu = nn.ReLU()

    def forward(self, inputs):
        outs = self.embedding(inputs)
        outs = torch.flatten(outs, start_dim=1)
        outs = self.hidden(outs)
        outs = self.relu(outs)
        outs = self.hidden_l(outs)
        outs = self.relu(outs)
        outs = self.hidden_l(outs)
        outs = self.relu(outs)
        logits = self.classify(outs)
        return logits

# %% [markdown]
# ### Train Model

# %%
dataloader = DataLoader(
    list(zip(y, X)),
    batch_size=batch_size,
    shuffle=True,
)

model = SimpleLM(vocab.__len__(), embedding_dim).to(device)

optimizer = torch.optim.AdamW(model.parameters(), lr=0.001)

for epoch in range(epochs):
    for labels, seqs in dataloader:
        # optimize
        optimizer.zero_grad()
        logits = model(seqs.to(device))
        loss = F.cross_entropy(logits, labels.to(device))
        loss.backward()
        optimizer.step()
        # calculate accuracy
        pred_labels = logits.argmax(dim=1)
        num_correct = (pred_labels == labels.to(device)).float().sum()
        accuracy = num_correct / len(labels)
        print("Epoch {} - loss: {:2.4f} - accuracy: {:2.4f}".format(epoch+1, loss.item(), accuracy), end="\r")
    print("")

# %% [markdown]
# ### Text Generation

# %%
start_index = stoi["<start>"]
end_index = stoi["<end>"]
max_output = 128

def pred_output(sentence, progressive_output=True):
    test_seq = vocab(tokenizer.tokenize(sentence))
    test_seq.insert(0, start_index)
    for loop in range(max_output):
        input_tensor = torch.tensor([test_seq[-5:]], dtype=torch.int64).to(device)
        pred_logits = model(input_tensor)
        pred_index = pred_logits.argmax()
        test_seq.append(pred_index.item())
        if progressive_output:
            for i in test_seq:
                print(itos[i], end=" ")
            print("\n")
        if pred_index.item() == end_index:
            break
    return test_seq

# %%
_ = pred_output("in the united states president", progressive_output=True)
_ = pred_output("the man has accused by", progressive_output=True)
_ = pred_output("now he was expected to", progressive_output=True)

# %% [markdown]
# ## Re-train Tokenizer

# %% [markdown]
# ### Tokenization

# %%
training_corpus = (
    train_data[i : i + 1000]
    for i in range(0, len(train_data), 1000)
)

# create tokenizer
tokenizer = BertTokenizerFast.from_pretrained('bert-base-cased')

# Train tokenizer
tokenizer = tokenizer.train_new_from_iterator(training_corpus, 52000)

# define tokenization function
def yield_tokens(data):
    for text in data:
        tokens = tokenizer.tokenize(text)
        yield tokens

# build vocabulary list
vocab = Vocab(
    train_data,
    tokenization=yield_tokens,
    special_token=["<unk>"],
    max_tokens=max_word,
)

# get list for index-to-word, and word-to-index.
itos = vocab.get_itos()
stoi = vocab.get_stoi()

# %% [markdown]
# ### Train-Test Split

# %%
seq_len = 5 + 1
input_seq = []
for s in train_data:
    token_list = vocab(tokenizer.tokenize(s))
    for i in range(seq_len, len(token_list) + 1):
        seq_list = token_list[i-seq_len:i]
        input_seq.append(seq_list)
print("The number of training input sequence :{}".format(len(input_seq)))
input_seq = np.array(input_seq)

# %%
X, y = input_seq[:,:-1], input_seq[:,-1]

# %% [markdown]
# ### Train Model

# %%
dataloader = DataLoader(
    list(zip(y, X)),
    batch_size=batch_size,
    shuffle=True,
)

model = SimpleLM(vocab.__len__(), embedding_dim).to(device)

optimizer = torch.optim.AdamW(model.parameters(), lr=0.001)

for epoch in range(epochs):
    for labels, seqs in dataloader:
        # optimize
        optimizer.zero_grad()
        logits = model(seqs.to(device))
        loss = F.cross_entropy(logits, labels.to(device))
        loss.backward()
        optimizer.step()
        # calculate accuracy
        pred_labels = logits.argmax(dim=1)
        num_correct = (pred_labels == labels.to(device)).float().sum()
        accuracy = num_correct / len(labels)
        print("Epoch {} - loss: {:2.4f} - accuracy: {:2.4f}".format(epoch+1, loss.item(), accuracy), end="\r")
    print("")

# %% [markdown]
# ### Text Generation

# %%
_ = pred_output("in the united states president", progressive_output=True)
_ = pred_output("the man has accused by", progressive_output=True)
_ = pred_output("now he was expected to", progressive_output=True)
